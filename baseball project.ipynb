# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('baseball.csv')

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# The problem statement already mentioned that column (W) is our output. this column is the first column in the table.
# This dataset contains only numerical data and the Output seems to be a continious data and as such it is a regression problem.

# %%
df.head(5)
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail(5)
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %% [markdown]
# # EDA

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# The dataset contains 30rows and 17columns

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# This shows that all the columns are of interger datatype except ERA which is float

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# this shows that there are no null values present in the dataset.

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# This shows that there is no null values and that the datatype matches each columns

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# the heatmap  show the dataset is clean and contains no missing value.

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64
#
#
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: R, dtype: int64
#
#
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# ...

# %% [markdown]
# From above we can see that that the target variable is not categorical in nature and that there is no hidden missing value
# which means the data is clean.

# %%
df.nunique().to_frame('No of unique value')
# Out:
#      No of unique value
# W                    24
# R                    28
# AB                   29
# H                    29
# 2B                   22
# 3B                   23
# HR                   27
# BB                   29
# SO                   29
# SB                   27
# RA                   30
# ER                   30
# ERA                  30
# CG                    9
# SHO                  12
# SV                   20
# E                    21

# %% [markdown]
# # description of Data

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# from above we can infer;
# 1. The count of all the columns are same which means there is no missing data.
# 2.The standard deviation is high which means the data are not normally distributed in all the columns except in ERA and CG.
# 3.The mean is greater than median in all the columns AB, H,HR, SV and E which suggest right skewness. while the median is greater than the mean
# in BB, SO, RA and ER which suggest right skewness and the difference between the mean and median in the rest of the columns are not
# significant and as such ther is no skewness or little skewness in the data.
# 4.The differnce between the max and 75% in columns are high except ERA, this suggest possible ouliers present in the data.

# %%
print('Total Duplicate rows',df.duplicated().sum())
# Out:
# Total Duplicate rows 0

# %% [markdown]
# This shows that there is no duplicate data present in the data set

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(10,6),facecolor='white')
plotnumber =1
for col in df:
    if plotnumber<=17:
        ax=plt.subplot(5,4,plotnumber) 
        sns.distplot(df[col],color='m')
        plt.xlabel(col,fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber +=1
plt.tight_layout()

# %% [markdown]
# Here we can see the distribution of the data.
# we can observe that ther is no too much deviation or skewness present in the data.

# %%
plt.title('Comparison beteween R and AB')
sns.scatterplot(y='R', x='AB',data=df,palette='bright')
plt.show()

# %% [markdown]
# This scatter plot shows that there is no definate relation between AB and R
# it does show slight positive correlation.

# %%
plt.title('Comparison beteween R and H')
sns.scatterplot(y='R', x='H',data=df,palette='bright')
plt.show()

# %% [markdown]
# the relation between H and R seems to be segmented into 3 parts and each part showing positive relationship

# %%
plt.title('Comparison beteween AB and H')
sns.scatterplot(y='AB', x='H',data=df,palette='bright')
plt.show()

# %% [markdown]
# Also, there is n definite relationship between H and AB

# %%
plt.title('Comparison beteween 2B and 3B')
sns.scatterplot(y='2B', x='3B',data=df,palette='bright')
plt.show()

# %%
plt.title('Comparison beteween 3B and HR')
sns.scatterplot(y='3B', x='HR',data=df,palette='bright')
plt.show()

# %% [markdown]
# Here, ther seems to be a negative correlation  between 3B and HR

# %%
plt.title('Comparison beteween R and AB')
sns.scatterplot(y='BB', x='HR',data=df,palette='bright')
plt.show()

# %% [markdown]
# the is no definite relationship between HR and BB

# %%
plt.title('Comparison beteween BB and SO')
sns.scatterplot(y='BB', x='SO',data=df,palette='bright')
plt.show()

# %%
sns.relplot(data=df, x="RA", y="SB", hue="W")

# %%
sns.relplot(data=df, x="ER", y="ERA", hue="W")

# %% [markdown]
# There is a positive relationship between the ER and ERA, ER increases as ERA increases

# %%
sns.relplot(data=df, x="SHO", y="SV", hue="W")

# %%
sns.relplot(data=df, x="SV", y="E", hue="W")

# %%
sns.pairplot(df,hue='W',palette='Dark2')
plt.show()

# %% [markdown]
# here we can see a pairwise plot between the columns
# we can see a positive relationship between ERA and ER and ER in relationship with the target variable

# %%
plt.figure(figsize=(20,25))
p=1
for i in df:
    if p<=18:
        plt.subplot(5,4,p)
        sns.regplot(x='W',y=i,data=df,color='r')
        plt.xlabel('W')
        plt.ylabel(i)
    p+=1
plt.show()

# %% [markdown]
# The regplot above shows slight positive correlation between w sand 2B
# also it show negative relationship between w and  ERA,ER and RA

# %%
plt.figure(figsize=(15,15),facecolor='white')
plotnumber=1
for col in df:
    if plotnumber<=18:
        ax=plt.subplot(5,4,plotnumber)
        sns.boxplot(df[col],palette='Set2_r')
        plt.xlabel(col,fontsize=15)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# The boxplot above shows us the columns with outliers
# we can see columns E, SV, SHO, ERA and R have outliers present in them with colum E have the most significant outliers

# %%
from scipy.stats import zscore
out_features=df[['E','R','SHO', 'SV']]
z=np.abs(zscore(out_features))
z
# Out:
#            E         R       SHO        SV
# 0   0.461470  0.619078  0.814629  1.671607
# 1   0.607197  0.134432  0.172800  0.249879
# 2   1.117242  0.332906  0.320914  0.654856
# 3   0.485758  1.146419  0.567771  0.784104
# 4   0.607197  0.013270  0.172800  1.042600
# 5   0.461470  3.509647  0.320914  1.171848
# 6   0.097152  1.311430  1.802057  0.637623
# 7   1.262970  0.428681  0.320914  0.008617
# 8   0.048576  0.765626  0.172800  2.188598
# 9   0.194303  1.034489  0.320914  0.396360
# 10  1.797303  1.086415  0.567771  0.249879
# 11  0.680061  0.705622  0.419657  0.525608
# 12  0.097152  0.471376  0.172800  0.379127
# 13  0.024288  0.557920  0.172800  0.249879
# 14  2.307348  0.099814  0.913371  1.947335
# 15  0.121439  0.713699  0.913371  2.447094
# 16  2.015894  0.151740  0.419657  1.413111
# 17  1.214394  0.013270  2.394514  0.637623
# 18  1.578712  0.575229  1.061486  0.396360
# 19  0.315742  0.834861  0.814629  1.042600
# 20  0.461470  0.090583  0.666514  0.896119
# ...

# %% [markdown]
# here we calculate Zscore in a bis to be able to condition the dataset to eliminate the outliers

# %%
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
df1=df[(z<3).all(axis=1)]
df1.shape
# Out:
# (29, 17)

# %%
print('old dataframe:', df.shape[0])
print('new dataframe:', df1.shape[0])
# Out:
# old dataframe: 30
# new dataframe: 29

# %%
print('Data loss percentage:', ((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data loss percentage: 3.3333333333333335

# %% [markdown]
# after removing the outliers we can see the percentage of the data loss is not significant and as such data loss is acceptable

# %%
df=df1

# %%
plt.figure(figsize=(15,15),facecolor='white')
plotnumber=1
for column in df:
    if plotnumber <=18:
        ax=plt.subplot(6,4,plotnumber)
        sns.distplot(df[column],color='b')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# after remover of the outliers we check the distribution again, we still notice skewness present in this columns

# %% [markdown]
# # checking skewness

# %%
df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# we are checking for skewness here and we see that both columns E, CG,H and SV have skewness above the limit

# %%
df['E']=np.cbrt(df['E'])

# %%
df['SV']=np.cbrt(df['SV'])

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.390451 -0.085780 -0.018360  0.384886 -0.206737  0.245697
# R    0.390451  1.000000  0.438022  0.433525  0.469293  0.134204  0.586894
# AB  -0.085780  0.438022  1.000000  0.769159  0.490752  0.445604 -0.064653
# H   -0.018360  0.433525  0.769159  1.000000  0.528016  0.582024 -0.218711
# 2B   0.384886  0.469293  0.490752  0.528016  1.000000  0.342419 -0.098695
# 3B  -0.206737  0.134204  0.445604  0.582024  0.342419  1.000000 -0.369299
# HR   0.245697  0.586894 -0.064653 -0.218711 -0.098695 -0.369299  1.000000
# BB   0.447513  0.258450 -0.137850 -0.222271  0.211243 -0.404852  0.336814
# SO   0.156469  0.081158 -0.111243 -0.371861 -0.096772 -0.196586  0.479914
# SB  -0.169503  0.075323  0.373674  0.417877  0.194308  0.483818 -0.166072
# RA  -0.823176 -0.013858  0.315499  0.244606 -0.215196  0.312750 -0.092586
# ER  -0.815308  0.007727  0.309146  0.280571 -0.224993  0.333731 -0.062094
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot=True,fmt='0.2f',linewidth=0.2,linecolor='black',cmap='Spectral')
plt.xlabel('figure',fontsize=14)
plt.ylabel('feature_name', fontsize=14)
plt.title('Descriptive Graph', fontsize=20)
plt.show()

# %% [markdown]
# from the correlation table above,
# 1. We can see that W has a very high negative correlation with RA, ERA and ER
# 2. W has a high positive correlation with SV and medium correlation with SHO and BB
# 3.there is also high correlation between AB and H
# 4.there is medium correlation between R and HR, also medium coreelation 3B and H, also medium correlation between HR and R
# 5.also ther is ngative correlation between SHO and ER,ERAand RA

# %%
df1.drop('ERA', axis=1, inplace=True)

# %%
df1.drop('SV', axis=1,inplace=True)

# %%
df1.drop('RA', axis=1,inplace=True)

# %% [markdown]
# the columns with high negive correlation were drop because of the negative impact on the target variable.

# %%
df1.shape
# Out:
# (29, 14)

# %%
plt.figure(figsize=(17,8))
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind= 'bar',color='m')
plt.xlabel('feature',fontsize=15)
plt.ylabel('Target',fontsize=15)
plt.title('correlation between label and features using', fontsize=20)
plt.show()

# %% [markdown]
# # seprating features

# %%
x=df1.drop('W', axis=1)
y=df1['W']
print('feature Dimension',x.shape)
print('Label Dimention',y.shape)
# Out:
# feature Dimension (29, 13)
# Label Dimention (29,)

# %% [markdown]
# we separeted the target variable from the independent variable

# %% [markdown]
# # scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.959398  0.830084  1.738306  1.556538  1.010845 -0.765863 -1.536359
# 1   0.331147 -0.702831 -0.938698  0.201171  1.208917 -0.181389 -0.495021
# 2  -0.274666 -1.100253 -0.106656  1.733325 -0.276617 -0.697101  1.252941
# 3  -1.329231  0.233951 -0.359886 -0.800621 -0.474688 -0.869006 -1.145857
# 4   0.174084  1.255894  2.063888  0.908319  1.704094 -0.353293 -0.197495
# 5   1.856900  0.716535 -0.070480 -0.093474 -1.266972  1.743939  1.643442
# 6   0.712585 -0.447345 -0.558853 -1.625627 -1.167936  1.915843 -0.885522
# 7  -0.835605 -0.447345 -0.323710  0.260100  0.020490  0.196801 -0.550807
# 8   1.497899  1.752672  1.702131  1.202964  0.119526 -0.009484  0.230197
# 9   1.565212 -0.078310  0.327453  0.319029  0.020490  0.368705  0.695081
# 10  1.071586 -0.816380 -0.685468  0.260100 -0.573723  2.362794  0.378960
# 11 -0.454167 -1.412514 -1.264279 -1.802414 -1.068901  0.506228 -0.569402
# ...

# %% [markdown]
# we apply scaling to help improve the result of our model. this adjusted the data in a range.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['vif values']=[variance_inflation_factor(x.values,i)for i in range (len(x.columns))]
vif['feature']=x.columns
vif
# Out:
#     vif values feature
# 0     6.044232       R
# 1     4.514189      AB
# 2     7.196905       H
# 3     3.078277      2B
# 4     3.216064      3B
# 5     5.954142      HR
# 6     2.923587      BB
# 7     2.119707      SO
# 8     1.673172      SB
# 9     3.705855      ER
# 10    1.857246      CG
# 11    3.067210     SHO
# 12    1.988792       E

# %% [markdown]
# from above we check for the overfitting or underfitting in our data by calculatiing the variance inflation factor

# %%
x.drop('H', axis=1, inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['vif values']=[variance_inflation_factor(x.values,i)for i in range (len(x.columns))]
vif['feature']=x.columns
vif
# Out:
#     vif values feature
# 0     4.359100       R
# 1     2.511136      AB
# 2     3.048506      2B
# 3     3.192122      3B
# 4     4.715723      HR
# 5     2.615165      BB
# 6     2.093097      SO
# 7     1.550262      SB
# 8     3.586962      ER
# 9     1.770957      CG
# 10    2.918408     SHO
# 11    1.423159       E

# %% [markdown]
# # Modelling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor 
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
maxAccu=0
maxRS=0
for i in range (1,29):
    x_train,x_test, y_train,y_test=train_test_split(x,y,test_size=.30, random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRs=i
print('maximum r2 score is', maxAccu,'on random_state', maxRs)
# Out:
# maximum r2 score is 0.8361582620528722 on random_state 13

# %%
x_train,x_test, y_train,y_test=train_test_split(x,y,test_size=.30, random_state=maxRs)

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print('r2_score:', r2_score(y_test,pred_LR))
print('r2_score on training data:', r2_score(y_train,pred_train)*100)
print('mean absolute error:', mean_absolute_error(y_test,pred_LR))
print('mean squared error:', mean_squared_error(y_test,pred_LR))
print('root mean squared error:', np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# r2_score: 0.8361582620528722
# r2_score on training data: 81.58512362431993
# mean absolute error: 3.2165798191724
# mean squared error: 15.757125168001542
# root mean squared error: 3.9695245518829507

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_LR,y=y_test,color='r')
plt.plot(pred_LR,pred_LR, color='b')
plt.xlabel('Actaual', fontsize=14)
plt.ylabel('predict',fontsize=14)
plt.title('linear regression',fontsize=18)
plt.show()

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print('r2_score:', r2_score(y_test,pred_RFR))
print('r2_score on training data:', r2_score(y_train,pred_train)*100)
print('mean absolute error:', mean_absolute_error(y_test,pred_RFR))
print('mean squared error:', mean_squared_error(y_test,pred_RFR))
print('root mean squared error:', np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# r2_score: 0.5912696790757381
# r2_score on training data: 87.97286497537404
# mean absolute error: 5.791111111111111
# mean squared error: 39.308755555555564
# root mean squared error: 6.269669493327026

# %%
knn=KNN()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
pred_train=LR.predict(x_train)
print('r2_score:', r2_score(y_test,pred_knn))
print('r2_score on training data:', r2_score(y_train,pred_train)*100)
print('mean absolute error:', mean_absolute_error(y_test,pred_knn))
print('mean squared error:', mean_squared_error(y_test,pred_knn))
print('root mean squared error:', np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# r2_score: 0.6286315789473685
# r2_score on training data: 81.58512362431993
# mean absolute error: 4.755555555555556
# mean squared error: 35.71555555555555
# root mean squared error: 5.976249288270658

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print('r2_score:', r2_score(y_test,pred_GBR))
print('r2_score on training data:', r2_score(y_train,pred_train)*100)
print('mean absolute error:', mean_absolute_error(y_test,pred_GBR))
print('mean squared error:', mean_squared_error(y_test,pred_GBR))
print('root mean squared error:', np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# r2_score: -0.27929186122248106
# r2_score on training data: 99.99999112275042
# mean absolute error: 9.974513124442987
# mean squared error: 123.03313085090284
# root mean squared error: 11.092030059953085

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
pred_lasso=lasso.predict(x_test)
pred_train=lasso.predict(x_train)
print('r2_score:', r2_score(y_test,pred_lasso))
print('r2_score on training data:', r2_score(y_train,pred_train)*100)
print('mean absolute error:', mean_absolute_error(y_test,pred_lasso))
print('mean squared error:', mean_squared_error(y_test,pred_lasso))
print('root mean squared error:', np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# r2_score: 0.8528200108503592
# r2_score on training data: 77.24784488412513
# mean absolute error: 3.1620222639135185
# mean squared error: 14.154717475008665
# root mean squared error: 3.762275571380792

# %%
rd=Ridge()
rd.fit(x_train,y_train)
pred_rd=LR.predict(x_test)
pred_train=LR.predict(x_train)
print('r2_score:', r2_score(y_test,pred_rd))
print('r2_score on training data:', r2_score(y_train,pred_train)*100)
print('mean absolute error:', mean_absolute_error(y_test,pred_rd))
print('mean squared error:', mean_squared_error(y_test,pred_rd))
print('root mean squared error:', np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# r2_score: 0.8361582620528722
# r2_score on training data: 81.58512362431993
# mean absolute error: 3.2165798191724
# mean squared error: 15.757125168001542
# root mean squared error: 3.9695245518829507

# %%
dtc=DecisionTreeRegressor()
dtc.fit(x_train,y_train)
pred_dtc=dtc.predict(x_test)
pred_train=dtc.predict(x_train)
print('r2_score:', r2_score(y_test,pred_dtc))
print('r2_score on training data:', r2_score(y_train,pred_train)*100)
print('mean absolute error:', mean_absolute_error(y_test,pred_dtc))
print('mean squared error:', mean_squared_error(y_test,pred_dtc))
print('root mean squared error:', np.sqrt(mean_squared_error(y_test,pred_dtc)))
# Out:
# r2_score: -1.1720154043645699
# r2_score on training data: 100.0
# mean absolute error: 12.444444444444445
# mean squared error: 208.88888888888889
# root mean squared error: 14.452988925785867

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
pred_train=svr.predict(x_train)
print('r2_score:', r2_score(y_test,pred_svr))
print('r2_score on training data:', r2_score(y_train,pred_train)*100)
print('mean absolute error:', mean_absolute_error(y_test,pred_svr))
print('mean squared error:', mean_squared_error(y_test,pred_svr))
print('root mean squared error:', np.sqrt(mean_squared_error(y_test,pred_svr)))
# Out:
# r2_score: 0.1177812300264045
# r2_score on training data: 20.06699127299052
# mean absolute error: 7.5757457322195485
# mean squared error: 84.84548417400383
# root mean squared error: 9.21116084834066

# %%
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_etr=etr.predict(x_test)
pred_train=etr.predict(x_train)
print('r2_score:', r2_score(y_test,pred_etr))
print('r2_score on training data:', r2_score(y_train,pred_train)*100)
print('mean absolute error:', mean_absolute_error(y_test,pred_etr))
print('mean squared error:', mean_squared_error(y_test,pred_etr))
print('root mean squared error:', np.sqrt(mean_squared_error(y_test,pred_etr)))
# Out:
# r2_score: 0.7605946854942235
# r2_score on training data: 100.0
# mean absolute error: 4.344444444444444
# mean squared error: 23.02428888888888
# root mean squared error: 4.7983631468333945

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(LR,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print('difference between r2 score and cross validation score is:',(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [ 0.2935209  -2.42298309  0.29080015  0.75503707  0.81337445]
# -0.054050103653495093
# difference between r2 score and cross validation score is: 89.02083657063673

# %%
score=cross_val_score(RFR,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print('difference between r2 score and cross validation score is:',(r2_score(y_test,pred_RFR)-score.mean())*100)
# Out:
# [-0.27151284 -4.39624868  0.28097231  0.23095525  0.68071197]
# -0.695024399407707
# difference between r2 score and cross validation score is: 128.6294078483445

# %%
score=cross_val_score(knn,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print('difference between r2 score and cross validation score is:',(r2_score(y_test,pred_knn)-score.mean())*100)
# Out:
# [-0.25277273 -1.61526316  0.21696361  0.21783607  0.49799528]
# -0.18704818460480166
# difference between r2 score and cross validation score is: 81.56797635521701

# %%
score=cross_val_score(GBR,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print('difference between r2 score and cross validation score is:',(r2_score(y_test,pred_GBR)-score.mean())*100)
# Out:
# [-0.30497603 -7.29816552  0.38865203  0.27265452  0.04592859]
# -1.3791812836996455
# difference between r2 score and cross validation score is: 109.98894224771645

# %%
score=cross_val_score(lasso,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print('difference between r2 score and cross validation score is:',(r2_score(y_test,pred_lasso)-score.mean())*100)
# Out:
# [ 0.4537445  -0.62744075  0.60894382  0.68898185  0.91954877]
# 0.4087556386060583
# difference between r2 score and cross validation score is: 44.40643722443009

# %%
score5=cross_val_score(rd,x,y, cv=5, scoring='r2')
print(score5)
print(score5.mean())
print('difference between r2 score and cross validation score is:',(r2_score(y_test,pred_rd)-score5.mean())*100)
# Out:
# [ 0.18857046 -2.13720746  0.4164034   0.73017809  0.87622532]
# 0.014833962560368907
# difference between r2 score and cross validation score is: 82.13242994925032

# %%
score=cross_val_score(dtc,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print('difference between r2 score and cross validation score is:',(r2_score(y_test,pred_dtc)-score.mean())*100)
# Out:
# [-0.99772727 -9.96052632  0.09159348  0.26557377 -0.14386792]
# -2.148990853403999
# difference between r2 score and cross validation score is: 97.69754490394291

# %%
score=cross_val_score(svr,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print('difference between r2 score and cross validation score is:',(r2_score(y_test,pred_svr)-score.mean())*100)
# Out:
# [-0.11236921 -1.20641297 -0.00714674 -0.47376598  0.1583061 ]
# -0.328277758478218
# difference between r2 score and cross validation score is: 44.60589885046225

# %%
score=cross_val_score(etr,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print('difference between r2 score and cross validation score is:',(r2_score(y_test,pred_etr)-score.mean())*100)
# Out:
# [-0.68708273 -3.07319737  0.42187227  0.06616492  0.70539623]
# -0.5133693360459178
# difference between r2 score and cross validation score is: 127.39640215401413

# %% [markdown]
# we chose lasso as our best performing model because the difference between r2 score and cross validation is least among all the model used.

# %%
from sklearn.model_selection import GridSearchCV
param= {'alpha':[1.0,.05,.4,2.0],'fit_intercept':[True,False],
       'selection':['cyclic', 'random'],
       'positive':[False,True],'random_state':[1,4,10,20]}
gscv=GridSearchCV(Lasso(),param, cv=5)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [1.0, 0.05, 0.4, 2.0],
#                          'fit_intercept': [True, False],
#                          'positive': [False, True],
#                          'random_state': [1, 4, 10, 20],
#                          'selection': ['cyclic', 'random']})

# %%
gscv.best_params_
# Out:
# {'alpha': 2.0,
#  'fit_intercept': True,
#  'positive': False,
#  'random_state': 20,
#  'selection': 'random'}

# %%
model=Lasso(alpha=2.0,fit_intercept=True,positive=False,random_state=20,selection='random')

# %%
model.fit(x_train,y_train)
pred=model.predict(x_test)
print('r2_score:', r2_score(y_test,pred))
print('mean absolute error:',mean_absolute_error(y_test,pred))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# r2_score: 0.787593792234521
# mean absolute error: 3.6792529289062736
# root mean squared error: 4.519702216910338

# %%
import joblib
joblib.dump(model,'baseball.pkl')
# Out:
# ['baseball.pkl']
