# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('world happiness')

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# # exploratory Data analysis

# %%
df.shape
# Out:
# (158, 12)

# %% [markdown]
# this tells us that we have 158 rows and 12 columns present in the dataset

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# this shows the list of the columns present in the dataset

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# this shows that the data are all in the correct data type

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# this shows that there is no null values present in the data

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# this above give informataion about the columns and the data types of each columns.

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: Country, Length: 158, dtype: int64
#
#
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64
#
#
# 82     2
# 1      1
# 110    1
# 103    1
# 104    1
#       ..
# 54     1
# 55     1
# 56     1
# 57     1
# 158    1
# Name: Happiness Rank, Length: 157, dtype: int64
#
#
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# ...

# %% [markdown]
# from the above we can say only column region is categorical in nature and there is missing values in any
# of the columns
# happiness rank can be drop from the dataset because it has a unique number to the happiness score.

# %%
df.set_index('Country', inplace=True)

# %%
df.head()
# Out:
#                      Region  Happiness Rank  Happiness Score  Standard Error  \
# Country
# Switzerland  Western Europe               1            7.587         0.03411
# Iceland      Western Europe               2            7.561         0.04884
# Denmark      Western Europe               3            7.527         0.03328
# Norway       Western Europe               4            7.522         0.03880
# Canada        North America               5            7.427         0.03553
#
#              Economy (GDP per Capita)   Family  Health (Life Expectancy)  \
# Country
# Switzerland                   1.39651  1.34951                   0.94143
# Iceland                       1.30232  1.40223                   0.94784
# Denmark                       1.32548  1.36058                   0.87464
# Norway                        1.45900  1.33095                   0.88521
# Canada                        1.32629  1.32261                   0.90563
#
# ...

# %% [markdown]
# country has been set as index

# %%
df.shape
# Out:
# (158, 11)

# %%
df.nunique().to_frame('no of unique values')
# Out:
#                                no of unique values
# Region                                          10
# Happiness Rank                                 157
# Happiness Score                                157
# Standard Error                                 153
# Economy (GDP per Capita)                       158
# Family                                         158
# Health (Life Expectancy)                       157
# Freedom                                        158
# Trust (Government Corruption)                  157
# Generosity                                     158
# Dystopia Residual                              158

# %%
df.drop('Happiness Rank',axis=1, inplace=True)

# %%
df.tail()
# Out:
#                                   Region  Happiness Score  Standard Error  \
# Country
# Rwanda                Sub-Saharan Africa            3.465         0.03464
# Benin                 Sub-Saharan Africa            3.340         0.03656
# Syria    Middle East and Northern Africa            3.006         0.05015
# Burundi               Sub-Saharan Africa            2.905         0.08658
# Togo                  Sub-Saharan Africa            2.839         0.06727
#
#          Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# Country
# Rwanda                    0.22208  0.77370                   0.42864  0.59201
# Benin                     0.28665  0.35386                   0.31910  0.48450
# Syria                     0.66320  0.47489                   0.72193  0.15684
# Burundi                   0.01530  0.41587                   0.22396  0.11850
# Togo                      0.20868  0.13995                   0.28443  0.36453
#
# ...

# %%
df.shape
# Out:
# (158, 10)

# %% [markdown]
# checking the number of unique values of each column

# %%
print('Total Duplicate rows',df.duplicated().sum())
# Out:
# Total Duplicate rows 0

# %%
categorical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        categorical_col.append(i)
print('categorical columns:', categorical_col)
print('\n')
# Out:
# categorical columns: ['Region']

# %%
numerical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]!='object':
        numerical_col.append(i)
print('numerical columns:', numerical_col)
print('\n')
# Out:
# numerical columns: ['Happiness Score', 'Standard Error', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']

# %% [markdown]
# # statistical anaysis

# %%
df.describe()
# Out:
#        Happiness Score  Standard Error  Economy (GDP per Capita)      Family  \
# count       158.000000      158.000000                158.000000  158.000000
# mean          5.375734        0.047885                  0.846137    0.991046
# std           1.145010        0.017146                  0.403121    0.272369
# min           2.839000        0.018480                  0.000000    0.000000
# 25%           4.526000        0.037268                  0.545808    0.856823
# 50%           5.232500        0.043940                  0.910245    1.029510
# 75%           6.243750        0.052300                  1.158448    1.214405
# max           7.587000        0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# ...

# %% [markdown]
# This give statistical information of the numerical columns. the summary looks perfect since there is no negative/invalid present.
# the following can be observed from the above.
# 1)the counts of all the columns are same which means there are no missing values
# 2) The standard deviation of all the columns is within range which means the the data are normally distributed.
# 3) there is no skewness in the columns.
# 4) the data doesn't appear to have an outliers as the difference in max value and 75percentile are
# not much.

# %%
plt.figure(figsize=(22,10))
sns.heatmap(df.describe(),annot=True,fmt='0.2f',linewidth=0.2,linecolor='black',cmap='Spectral')
plt.xlabel('figure',fontsize=14)
plt.ylabel('feature_name', fontsize=14)
plt.title('Descriptive Graph', fontsize=20)
plt.show()

# %% [markdown]
# # Data visualization

# %%
sns.lmplot(x='Standard Error',y='Happiness Score',data=df,palette='colorblind')

# %% [markdown]
# there is no relationship between the error and the Happiness score

# %%
sns.lmplot(x='Economy (GDP per Capita)',y='Happiness Score',data=df,palette='colorblind')

# %% [markdown]
# there seems to be a linear relationship between Happiness score and GDP

# %%
sns.lmplot(x='Family',y='Happiness Score',data=df,palette='colorblind')

# %%
sns.lmplot(x='Health (Life Expectancy)',y='Happiness Score',data=df,palette='colorblind')

# %% [markdown]
# happiness score has a positive relationship with health

# %%
sns.lmplot(x='Freedom',y='Happiness Score',data=df,palette='colorblind')

# %% [markdown]
# happiness score has a positive relationship with Freedom

# %%
sns.lmplot(x='Trust (Government Corruption)',y='Happiness Score',data=df,palette='colorblind')

# %%
sns.lmplot(x='Generosity',y='Happiness Score',data=df,palette='colorblind')

# %%
sns.lmplot(x='Dystopia Residual',y='Happiness Score',data=df,palette='colorblind')

# %% [markdown]
# happiness score has a positive relationship with dystopia residual

# %%
plt.figure(figsize=(10,6),facecolor='white')
plotnumber =1
for col in numerical_col:
    if plotnumber<=12:
        ax=plt.subplot(3,5,plotnumber)
        sns.distplot(df[col],color='m')
        plt.xlabel(col,fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber +=1
plt.tight_layout()

# %% [markdown]
# data seem normally distributed, Trust(government corruption) has slight right skewness and family has
# slight left skewness

# %%
ax=sns.countplot(x='Region',data=df)
print(df['Region'].value_counts())
plt.figure(figsize=(30,35))
plt.show()
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %%
plt.title('Comparison beteween region and Happiness score')
sns.stripplot(x='Region', y='Happiness Score',data=df)
plt.xticks(rotation=45)
plt.show()

# %%
plt.title('Comparison beteween region and Economy')
sns.stripplot(x='Region', y='Economy (GDP per Capita)',data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# from here we can see that the Economy of the country in western Europe are close
# the economy of country in sub-saharan africa is the lowest and is disperse wildy amony the country in the region

# %%
plt.title('Comparison beteween region and Trust')
sns.stripplot(x='Region', y='Trust (Government Corruption)',data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Among the country in western europe the Trust in government varies largely
# in central and eastern europe the Trust in government is close among the country's in the region
# subsaharan Africa has the highest values, this represnt one country and majority of the country in this
# region has low value.

# %%
plt.title('Comparison beteween region and Freedom')
sns.stripplot(x='Region', y='Freedom',data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# middle east and northern africa region has the country with the lowest value of Freedom.
# freedom values western europe is high in most country
# Generally the freedom value in all region are disperse

# %%
plt.title('Comparison beteween region and Health Life Expectancy')
sns.stripplot(x='Region', y='Health (Life Expectancy)',data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# the life expetancy amony country in western europe is high and are close together
# the life expectancy sub-saharan Africa is low and are close.
# the life expectancy in all region are close among the country in the region

# %%
plt.title('Comparison beteween region and Dystopia Residua')
sns.stripplot(x='Region', y='Dystopia Residual',data=df)
plt.xticks(rotation=45)
plt.show()

# %%
plt.title('Comparison beteween region and Generosity')
sns.stripplot(x='Region', y='Generosity',data=df)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(20,25))
p=1
for i in df:
    if p<=17:
        plt.subplot(5,4,p)
        sns.scatterplot(x='Happiness Score',y=i,data=df,color='r')
        plt.xlabel('Hppiness Score')
        plt.ylabel(i)
    p+=1
plt.show()

# %% [markdown]
# we can see some positive relationship between Happiness Score and(Economy,family,freedomand health)

# %%
sns.pairplot(df)

# %% [markdown]
# # checking outliers

# %%
plt.figure(figsize=(20,25))
k=1
for i in numerical_col:
    if k<=15:
        plt.subplot(3,5,k)
        sns.boxplot(df[i], palette='Set2_r')
        plt.xlabel(i)
    k+=1
plt.show()

# %% [markdown]
# we can see some outliers in Trust, dystopia,standard error and family

# %%
from scipy.stats import zscore
features=df[['Standard Error','Dystopia Residual','Trust (Government Corruption)']]
z=np.abs(zscore(features))
z
# Out:
#              Standard Error  Dystopia Residual  Trust (Government Corruption)
# Country
# Switzerland        0.805926           0.758258                       2.309652
# Iceland            0.055889           1.092857                       0.016480
# Denmark            0.854487           0.712335                       2.842774
# Norway             0.531526           0.663893                       1.852081
# Canada             0.722845           0.639337                       1.555725
# ...                     ...                ...                            ...
# Rwanda             0.774917           2.588925                       3.413922
# Benin              0.662582           0.843967                       0.529210
# Syria              0.132534           3.208430                       0.381419
# Burundi            2.263962           0.481985                       0.357715
# Togo               1.134182           0.963612                       0.301803
#
# [158 rows x 3 columns]

# %%
np.where(z>3)
# Out:
# (array([ 27,  40,  64, 115, 153, 155], dtype=int64),
#  array([2, 0, 0, 0, 2, 1], dtype=int64))

# %%
df1=df[(z<3).all(axis=1)]
df1.shape
# Out:
# (152, 10)

# %%
print('old dataframe:', df.shape[0])
print('new dataframe:', df1.shape[0])
# Out:
# old dataframe: 158
# new dataframe: 152

# %%
print('Data loss percentage:', ((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data loss percentage: 3.79746835443038

# %%
df=df1

# %% [markdown]
# # checking skewness

# %%
df.skew()
# Out:
# Happiness Score                  0.142020
# Standard Error                   1.196769
# Economy (GDP per Capita)        -0.363038
# Family                          -1.033362
# Health (Life Expectancy)        -0.713939
# Freedom                         -0.404907
# Trust (Government Corruption)    1.284825
# Generosity                       1.039230
# Dystopia Residual               -0.009316
# dtype: float64

# %% [markdown]
# there is skewness in standard error, family, health,Trust and Generosity

# %%
df['Standard Error']=np.cbrt(df['Standard Error'])

# %%
df.skew()
# Out:
# Happiness Score                  0.142020
# Standard Error                   0.497061
# Economy (GDP per Capita)        -0.363038
# Family                          -1.033362
# Health (Life Expectancy)        -0.713939
# Freedom                         -0.404907
# Trust (Government Corruption)    1.284825
# Generosity                       1.039230
# Dystopia Residual               -0.009316
# dtype: float64

# %%
from sklearn.preprocessing import OrdinalEncoder
OE=OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=OE.fit_transform(df[i].values.reshape(-1,1))

df
# Out:
#               Region  Happiness Score  Standard Error  \
# Country
# Switzerland      9.0            7.587        0.324310
# Iceland          9.0            7.561        0.365532
# Denmark          9.0            7.527        0.321658
# Norway           9.0            7.522        0.338540
# Canada           5.0            7.427        0.328749
# ...              ...              ...             ...
# Burkina Faso     8.0            3.587        0.350990
# Afghanistan      7.0            3.575        0.313597
# Benin            8.0            3.340        0.331896
# Burundi          8.0            2.905        0.442391
# Togo             8.0            2.839        0.406700
#
#               Economy (GDP per Capita)   Family  Health (Life Expectancy)  \
# Country
# Switzerland                    1.39651  1.34951                   0.94143
# Iceland                        1.30232  1.40223                   0.94784
# ...

# %% [markdown]
# # correllation

# %%
df.corr()
# Out:
#                                  Region  Happiness Score  Standard Error  \
# Region                         1.000000        -0.166865       -0.030871
# Happiness Score               -0.166865         1.000000       -0.260447
# Standard Error                -0.030871        -0.260447        1.000000
# Economy (GDP per Capita)      -0.242699         0.783649       -0.264108
# Family                        -0.161619         0.732443       -0.173754
# Health (Life Expectancy)      -0.348567         0.738745       -0.360626
# Freedom                        0.100666         0.569412       -0.200949
# Trust (Government Corruption)  0.161951         0.469992       -0.160488
# Generosity                     0.288852         0.206115       -0.151432
# Dystopia Residual             -0.060275         0.518903        0.027291
#
#                                Economy (GDP per Capita)    Family  \
# Region                                        -0.242699 -0.161619
# ...

# %%
plt.figure(figsize=(26,14))
sns.heatmap(df.corr(),annot=True,fmt='0.2f',linewidth=0.2,linecolor='black',cmap='Spectral')
plt.xlabel('figure',fontsize=14)
plt.ylabel('feature_name', fontsize=14)
plt.title('Descriptive Graph', fontsize=20)
plt.show()

# %% [markdown]
# the Happiness score is highly correlated with Economy, family and health.
# the happiness score is moderatly correlated with dystopia residual and freedom
# happiness Score has less coreelation with standard Error, region,generosity and Trust

# %%
cor=df.corr()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 152 entries, Switzerland to Togo
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Region                         152 non-null    float64
#  1   Happiness Score                152 non-null    float64
#  2   Standard Error                 152 non-null    float64
#  3   Economy (GDP per Capita)       152 non-null    float64
#  4   Family                         152 non-null    float64
#  5   Health (Life Expectancy)       152 non-null    float64
#  6   Freedom                        152 non-null    float64
#  7   Trust (Government Corruption)  152 non-null    float64
#  8   Generosity                     152 non-null    float64
#  9   Dystopia Residual              152 non-null    float64
# dtypes: float64(10)
# memory usage: 13.1+ KB

# %%
cor['Happiness Score'].sort_values(ascending=False)
# Out:
# Happiness Score                  1.000000
# Economy (GDP per Capita)         0.783649
# Health (Life Expectancy)         0.738745
# Family                           0.732443
# Freedom                          0.569412
# Dystopia Residual                0.518903
# Trust (Government Corruption)    0.469992
# Generosity                       0.206115
# Region                          -0.166865
# Standard Error                  -0.260447
# Name: Happiness Score, dtype: float64

# %% [markdown]
# this shows the correlation of eacg column to Happiness Score in descending order

# %%
plt.figure(figsize=(22,7))
df.corr()['Happiness Score'].sort_values(ascending=False).drop(['Happiness Score']).plot(kind= 'bar',color='m')
plt.xlabel('feature',fontsize=15)
plt.ylabel('Target',fontsize=15)
plt.title('correlation between label and features using', fontsize=20)
plt.show()

# %%
x=df.drop('Happiness Score', axis=1)
y=df['Happiness Score']

# %%
print('feature Dimension',x.shape)
print('Label Dimension',y.shape)
# Out:
# feature Dimension (152, 9)
# Label Dimension (152,)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#        Region  Standard Error  Economy (GDP per Capita)    Family  \
# 0    1.286680       -0.926171                  1.388746  1.307348
# 1    1.286680        0.272752                  1.149914  1.501384
# 2    1.286680       -1.003308                  1.208639  1.348091
# 3    1.286680       -0.512287                  1.547198  1.239038
# 4   -0.041506       -0.797055                  1.210693  1.208342
# ..        ...             ...                       ...       ...
# 147  0.954633       -0.150183                 -1.497801 -0.524184
# 148  0.622587       -1.237771                 -1.341352 -2.544893
# 149  0.954633       -0.705538                 -1.425460 -2.357151
# 150  0.954633        2.508172                 -2.113505 -2.128922
# 151  0.954633        1.470109                 -1.623163 -3.144448
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 0                    1.244908  1.597208                       2.494900
# ...

# %% [markdown]
# # variance inflation factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['vif values']=[variance_inflation_factor(x.values,i)for i in range (len(x.columns))]
vif['feature']=x.columns
vif
# Out:
#    vif values                        feature
# 0    1.421045                         Region
# 1    1.200177                 Standard Error
# 2    4.455606       Economy (GDP per Capita)
# 3    1.942873                         Family
# 4    4.100374       Health (Life Expectancy)
# 5    1.763359                        Freedom
# 6    1.492690  Trust (Government Corruption)
# 7    1.454764                     Generosity
# 8    1.035156              Dystopia Residual

# %% [markdown]
# Vif is okay and there seems to be no issue of multicollinearity

# %% [markdown]
# # modelling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
maxAccu=0
maxRS=0
for i in range (1,150):
    x_train,x_test, y_train,y_test=train_test_split(x,y,test_size=.30, random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRs=i
print('maximum r2 score is', maxAccu,'on random_state', maxRs)
# Out:
# maximum r2 score is 0.9999999578478445 on random_state 37

# %%
x_train,x_test, y_train,y_test=train_test_split(x,y,test_size=.30, random_state=maxRs)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor 
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print('r2_score:', r2_score(y_test,pred_LR))
print('r2_score on training data:', r2_score(y_train,pred_train)*100)
print('mean absolute error:', mean_absolute_error(y_test,pred_LR))
print('mean squared error:', mean_squared_error(y_test,pred_LR))
print('root mean squared error:', np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# r2_score: 0.9999999578478445
# r2_score on training data: 99.99999295763018
# mean absolute error: 0.00021949810397309014
# mean squared error: 6.937490796676423e-08
# root mean squared error: 0.0002633911691130973

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_LR,y=y_test,color='b')
plt.plot(pred_LR,pred_LR, color='g')
plt.xlabel('Actaual', fontsize=14)
plt.ylabel('predict',fontsize=14)
plt.title('linear regression',fontsize=18)
plt.show()

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print('r2_score:', r2_score(y_test,pred_GBR))
print('r2_score on training data:', r2_score(y_train,pred_train)*100)
print('mean absolute error:', mean_absolute_error(y_test,pred_GBR))
print('mean squared error:', mean_squared_error(y_test,pred_GBR))
print('root mean squared error:', np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# r2_score: 0.9369024980544636
# r2_score on training data: 99.95396069500735
# mean absolute error: 0.24908721812646678
# mean squared error: 0.10384720150250595
# root mean squared error: 0.3222533188386211

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print('r2_score:', r2_score(y_test,pred_RFR))
print('r2_score on training data:', r2_score(y_train,pred_train)*100)
print('mean absolute error:', mean_absolute_error(y_test,pred_RFR))
print('mean squared error:', mean_squared_error(y_test,pred_RFR))
print('root mean squared error:', np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# r2_score: 0.9051159000201042
# r2_score on training data: 98.73296676254417
# mean absolute error: 0.3061163043478258
# mean squared error: 0.15616225597173894
# root mean squared error: 0.3951737035428078

# %%
knn=KNN()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
pred_train=LR.predict(x_train)
print('r2_score:', r2_score(y_test,pred_knn))
print('r2_score on training data:', r2_score(y_train,pred_train)*100)
print('mean absolute error:', mean_absolute_error(y_test,pred_knn))
print('mean squared error:', mean_squared_error(y_test,pred_knn))
print('root mean squared error:', np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# r2_score: 0.9144061728593497
# r2_score on training data: 99.99999295763018
# mean absolute error: 0.3106869565217393
# mean squared error: 0.14087212869565224
# root mean squared error: 0.3753293602899355

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
pred_lasso=lasso.predict(x_test)
pred_train=lasso.predict(x_train)
print('r2_score:', r2_score(y_test,pred_lasso))
print('r2_score on training data:', r2_score(y_train,pred_train)*100)
print('mean absolute error:', mean_absolute_error(y_test,pred_lasso))
print('mean squared error:', mean_squared_error(y_test,pred_lasso))
print('root mean squared error:', np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# r2_score: -0.023021814246310113
# r2_score on training data: 0.0
# mean absolute error: 1.1289548810500412
# mean squared error: 1.6837109110467903
# root mean squared error: 1.29757886505861

# %%
rd=Ridge()
rd.fit(x_train,y_train)
pred_rd=LR.predict(x_test)
pred_train=LR.predict(x_train)
print('r2_score:', r2_score(y_test,pred_rd))
print('r2_score on training data:', r2_score(y_train,pred_train)*100)
print('mean absolute error:', mean_absolute_error(y_test,pred_rd))
print('mean squared error:', mean_squared_error(y_test,pred_rd))
print('root mean squared error:', np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# r2_score: 0.9999999578478445
# r2_score on training data: 99.99999295763018
# mean absolute error: 0.00021949810397309014
# mean squared error: 6.937490796676423e-08
# root mean squared error: 0.0002633911691130973

# %%
dtc=DecisionTreeRegressor()
dtc.fit(x_train,y_train)
pred_dtc=dtc.predict(x_test)
pred_train=dtc.predict(x_train)
print('r2_score:', r2_score(y_test,pred_dtc))
print('r2_score on training data:', r2_score(y_train,pred_train)*100)
print('mean absolute error:', mean_absolute_error(y_test,pred_dtc))
print('mean squared error:', mean_squared_error(y_test,pred_dtc))
print('root mean squared error:', np.sqrt(mean_squared_error(y_test,pred_dtc)))
# Out:
# r2_score: 0.7704453371069341
# r2_score on training data: 100.0
# mean absolute error: 0.47808695652173905
# mean squared error: 0.37780591304347827
# root mean squared error: 0.6146591844619896

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
pred_train=svr.predict(x_train)
print('r2_score:', r2_score(y_test,pred_svr))
print('r2_score on training data:', r2_score(y_train,pred_train)*100)
print('mean absolute error:', mean_absolute_error(y_test,pred_svr))
print('mean squared error:', mean_squared_error(y_test,pred_svr))
print('root mean squared error:', np.sqrt(mean_squared_error(y_test,pred_svr)))
# Out:
# r2_score: 0.9397129851820314
# r2_score on training data: 98.65882514956377
# mean absolute error: 0.2171721098537404
# mean squared error: 0.09922164242239113
# root mean squared error: 0.31499467046664636

# %%
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_etr=etr.predict(x_test)
pred_train=etr.predict(x_train)
print('r2_score:', r2_score(y_test,pred_etr))
print('r2_score on training data:', r2_score(y_train,pred_train)*100)
print('mean absolute error:', mean_absolute_error(y_test,pred_etr))
print('mean squared error:', mean_squared_error(y_test,pred_etr))
print('root mean squared error:', np.sqrt(mean_squared_error(y_test,pred_etr)))
# Out:
# r2_score: 0.9275760633717904
# r2_score on training data: 100.0
# mean absolute error: 0.2636639130434784
# mean squared error: 0.11919684470434787
# root mean squared error: 0.345248960468164

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(LR,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print('difference between r2 score and cross validation score is:',(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [0.99999948 0.99999837 0.99999789 0.99999564 0.99999938]
# 0.9999981535763528
# difference between r2 score and cross validation score is: 0.00018042714916566283

# %%
score=cross_val_score(RFR,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print('difference between r2 score and cross validation score is:',(r2_score(y_test,pred_RFR)-score.mean())*100)
# Out:
# [-7.0015214  -0.98385068 -1.54237038 -1.92160765 -5.48114094]
# -3.386098211253208
# difference between r2 score and cross validation score is: 429.12141112733127

# %%
score=cross_val_score(knn,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print('difference between r2 score and cross validation score is:',(r2_score(y_test,pred_knn)-score.mean())*100)
# Out:
# [-9.6888247  -2.5949806  -3.22919864 -7.74568388 -4.68226513]
# -5.58819058939991
# difference between r2 score and cross validation score is: 650.259676225926

# %%
score=cross_val_score(GBR,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print('difference between r2 score and cross validation score is:',(r2_score(y_test,pred_GBR)-score.mean())*100)
# Out:
# [-4.03778144 -0.43180038 -1.44502334 -2.08589815 -3.67934528]
# -2.3359697170569595
# difference between r2 score and cross validation score is: 327.2872215111423

# %%
score=cross_val_score(lasso,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print('difference between r2 score and cross validation score is:',(r2_score(y_test,pred_lasso)-score.mean())*100)
# Out:
# [-40.44866007 -11.7431237   -0.40158576 -30.6592645  -24.91142091]
# -21.632810988387178
# difference between r2 score and cross validation score is: 2160.978917414087

# %%
score5=cross_val_score(rd,x,y, cv=5, scoring='r2')
print(score5)
print(score5.mean())
print('difference between r2 score and cross validation score is:',(r2_score(y_test,pred_rd)-score5.mean())*100)
# Out:
# [0.9947478  0.99955836 0.99938814 0.99920638 0.99832911]
# 0.9982459586322724
# difference between r2 score and cross validation score is: 0.17539992155720663

# %%
score=cross_val_score(dtc,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print('difference between r2 score and cross validation score is:',(r2_score(y_test,pred_dtc)-score.mean())*100)
# Out:
# [ -4.81649572 -11.34201099 -10.94251087 -11.1773164   -5.39056369]
# -8.733779533545306
# difference between r2 score and cross validation score is: 950.4224870652241

# %%
score=cross_val_score(svr,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print('difference between r2 score and cross validation score is:',(r2_score(y_test,pred_svr)-score.mean())*100)
# Out:
# [-11.98951805   0.25296243   0.7721231   -0.07775668  -5.25198589]
# -3.258835018319523
# difference between r2 score and cross validation score is: 419.8548003501554

# %%
score=cross_val_score(etr,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print('difference between r2 score and cross validation score is:',(r2_score(y_test,pred_etr)-score.mean())*100)
# Out:
# [-7.1406007  -0.35450437 -1.67933168 -1.8664627  -4.63931157]
# -3.1360422047472505
# difference between r2 score and cross validation score is: 406.36182681190405

# %% [markdown]
# we can see that linear and ridge are the best performing model. we will go with ridge because
# ridge is regularization method for logistic itself.

# %%
from sklearn.model_selection import GridSearchCV
param= {'alpha':[1.0,.05,.4,2],'fit_intercept':[True,False],
       'solver':['auto','svd','cholesky','lsqr','sag','saga','ibfs'],
       'positive':[False,True],'random_state':[1,4,10,20]}
gscv=GridSearchCV(Ridge(),param, cv=5)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1.0, 0.05, 0.4, 2],
#                          'fit_intercept': [True, False],
#                          'positive': [False, True],
#                          'random_state': [1, 4, 10, 20],
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sag',
#                                     'saga', 'ibfs']})

# %%
gscv.best_params_
# Out:
# {'alpha': 1.0,
#  'fit_intercept': True,
#  'positive': False,
#  'random_state': 1,
#  'solver': 'auto'}

# %%
model=Ridge(alpha=1.0,fit_intercept=True,positive=False,random_state=1,solver='auto')

# %%
model.fit(x_train,y_train)
pred=model.predict(x_test)
print('r2_score:', r2_score(y_test,pred))
print('mean absolute error:',mean_absolute_error(y_test,pred))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# r2_score: 0.9999565175654519
# mean absolute error: 0.007225078064278103
# root mean squared error: 0.008459569093822016

# %%
import joblib
joblib.dump(model,'Happiness Score.pkl')
# Out:
# ['Happiness Score.pkl']
